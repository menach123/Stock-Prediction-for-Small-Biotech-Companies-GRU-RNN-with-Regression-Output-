# %%
import pandas as pd
import datetime
import json
import pandas_datareader as pdr
import numpy as np
import matplotlib.pyplot as plt
from keras import models
from keras import layers
from keras import optimizers
from matplotlib.image import imread
from keras.preprocessing import image
from helper import data_to_tensor
from keras.applications import ResNet50
from keras import optimizers
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# cnn_base = ResNet50(weights='imagenet',
#                   include_top=False,
#                   input_shape=(224, 224, 3))

# %% [markdown]
# cnn_base.summary()

# %% [markdown]
# model = models.Sequential()
# model.add(cnn_base)
# model.add(layers.Flatten())
# model.add(layers.Dense(32))
#
# model.add(layers.Dense(8, kernel_initializer='normal', activation = 'linear'))

# %% [markdown]
# model.layers[0].trainable = False
# model.layers[1].trainable = False

# %% [markdown]
# model.summary()

# %%
image_list= [f'C:/Users/FlatIron_User/capstone_stock/ITCI_{i}.png' for i in range(60,1000)]

# %%
with open('stock_info.json', 'r') as f:
    data = json.load(f)

# %%
stocks = [ stock for stock in data.keys()]

# %% [markdown]
# #### Next Day Max/Min Value  (% Difference from Closing Price)

# %%
start = datetime.datetime.now()
period = [1, 2]
for stock in stocks:
    
    stock_dict_list = data[stock]
    num_days = len(stock_dict_list)
    for index, dict_ in enumerate(stock_dict_list):
        _open = dict_['Open']
        if index+period[1] >= num_days:
            _low = None
            _max = None
        else:
            _low = np.min([dict_['Low'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
            _max = np.max([dict_['High'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
        stock_dict_list[index]['Low_1'] = _low
        stock_dict_list[index]['Max_1'] = _max
    data[stock] = stock_dict_list

# %% [markdown]
# #### 3 Day Max/Min Value (% Difference from Closing Price)
# The range is from the 2nd day to the 3rd after the input day

# %%
start = datetime.datetime.now()
period = [2, 4]
for stock in stocks:
    
    stock_dict_list = data[stock]
    num_days = len(stock_dict_list)
    for index, dict_ in enumerate(stock_dict_list):
        _open = dict_['Open']
        if index+period[1] >= num_days:
            _low = None
            _max = None
        else:
            _low = np.min([dict_['Low'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
            _max = np.max([dict_['High'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
        stock_dict_list[index]['Low_3'] = _low
        stock_dict_list[index]['Max_3'] = _max
    data[stock] = stock_dict_list

# %% [markdown]
# #### 10 Day Max/Min Value (% Difference from Closing Price)
# The range is from the 4th day to the 10th after the input day

# %%
start = datetime.datetime.now()
period = [4, 11]
for stock in stocks:
    
    stock_dict_list = data[stock]
    num_days = len(stock_dict_list)
    for index, dict_ in enumerate(stock_dict_list):
        _open = dict_['Open']
        if index+period[1] >= num_days:
            _low = None
            _max = None
        else:
            _low = np.min([dict_['Low'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
            _max = np.max([dict_['High'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
        stock_dict_list[index]['Low_10'] = _low
        stock_dict_list[index]['Max_10'] = _max
    data[stock] = stock_dict_list

# %% [markdown]
# #### 30 Day Max/Min Value (% Difference from Closing Price)
# The range is from the 11th day to the 30th after the input day

# %%
start = datetime.datetime.now()
period = [11, 31]
for stock in stocks:
    
    stock_dict_list = data[stock]
    num_days = len(stock_dict_list)
    for index, dict_ in enumerate(stock_dict_list):
        _open = dict_['Open']
        if index+period[1] >= num_days:
            _low = None
            _max = None
        else:
            _low = np.min([dict_['Low'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
            _max = np.max([dict_['High'] for dict_ in stock_dict_list[index+period[0]:index+period[1]]])/ _open -1
        stock_dict_list[index]['Low_30'] = _low
        stock_dict_list[index]['Max_30'] = _max
    data[stock] = stock_dict_list

# %% [markdown]
# #### Creating List of Dictionary to convert to a Dataframe

# %%
data_in_list = []
for stock in stocks:
    stock_dict_list = data[stock]
    for index, dict_ in enumerate(stock_dict_list):
        dict_['Ticker'] = stock
        data_in_list.append(dict_)
df = pd.DataFrame(data_in_list)   
print(len(df))
df.head()
# Out:
# 148088
#    Adj Close      Close                 Date   High        Low     Low_1  \
# 0  15.000000  15.000000  2014-01-07 00:00:00  17.00  15.000000  0.000000
# 1  17.000000  17.000000  2014-01-08 00:00:00  18.00  16.000000 -0.022857
# 2  17.500000  17.500000  2014-01-09 00:00:00  17.75  17.100000  0.000000
# 3  18.000000  18.000000  2014-01-10 00:00:00  20.00  17.500000  0.040000
# 4  18.200001  18.200001  2014-01-13 00:00:00  18.50  18.200001 -0.021739
#
#      Low_10     Low_3    Low_30     Max_1    Max_10     Max_3    Max_30  Open  \
# 0  0.125000  0.068750 -0.012500  0.125000  0.250000  0.250000  0.250000  16.0
# 1  0.028571  0.000000 -0.097143  0.014286  0.142857  0.142857  0.142857  17.5
# 2  0.028571  0.028571 -0.097143  0.142857  0.142857  0.100000  0.142857  17.5
# 3  0.040571  0.028571 -0.097143  0.057143  0.142857  0.100000  0.142857  17.5
# 4 -0.002717 -0.021739 -0.141304  0.046196  0.086957  0.032609  0.086957  18.4
#
#   Ticker    Volume
# 0   ITCI   59800.0
# 1   ITCI   51100.0
# 2   ITCI  159900.0
# 3   ITCI  157100.0
# 4   ITCI    5000.0

# %%
target = np.array(df.iloc[60:1000].loc[df.Ticker == 'ITCI'][['Low_1', 'Low_10', 'Low_3', 'Low_30', 'Max_1', 'Max_10', 'Max_3', 'Max_30']])

# %%
np.shape(target)
# Out:
# (940, 8)

# %%
np.shape(image_list)
# Out:
# (940,)

# %%
image_tensors = []
for image_location in image_list:
    img = image.load_img(image_location, target_size=(224, 224))
    img_tensor = image.img_to_array(img)
    img_tensor = np.expand_dims(img_tensor, axis=0)
    #Follow the Original Model Preprocessing
    img_tensor /= 255.
    image_tensors.append(img_tensor)

# %%
np.shape(image_tensors)
# Out:
# (940, 1, 224, 224, 3)

# %%
image_tensors = np.array(image_tensors)

# %%
image_tensors = image_tensors.reshape((940,224,224,3))

# %%
np.shape(image_tensors)
# Out:
# (940, 224, 224, 3)

# %% [markdown]
# model.compile(optimizer='adam', loss='mean_squared_error',metrics=['mean_squared_error'])

# %% [markdown]
# hist = model.fit(image_tensors, target, batch_size=32,
#                          epochs=10, validation_split=0.25)

# %% [markdown]
# model.evaluate(image_tensors, target)

# %% [markdown]
# predict = model.predict(image_tensors)

# %%
df = df.iloc[60:1000].loc[df.Ticker == 'ITCI']

# %%
list_ = []
for i in image_tensors:
    list_.append(i)
target_list = [i for i in target]

# %%
df['Image_Tensor']= list_
df['Target'] = target_list

# %% [markdown]
# df.to_csv('test.csv')

# %% [markdown]
# with open['test.json', 'w'] as f:
#     json.dump(image_tensors, f)

# %%
import sqlite3

# %%
conn = sqlite3.connect('new.db')

# %%
# Create the table
conn.execute("create table tensor (id, tensor)")

# %%
a = conn.execute("""
INSERT INTO tensor (id, tensor)
VALUES (?,?)
""", (index, tensor)).fetchall()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3b4ee86575d2> in <module>()
#       2 INSERT INTO tensor (id, tensor)
#       3 VALUES (?,?)
# ----> 4 """, (index, tensor)).fetchall()
#
# NameError: name 'tensor' is not defined

# %%
conn.fetchall()

# %%
for index, tensor in enumerate(list_):
    conn.execute("""
    INSERT INTO tensor (id, tensor)
    VALUES (?,?)
    """, (index, tensor)).fetchall()

# %%
a = conn.execute("""
SELECT *
FROM tensor
""").fetchall()

# %%
a[0]
# Out:
# (0,
#  b'\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x00\x80?\x00\x ...

# %%
stocks[50:]
# Out:
# ['GTHX',
#  'CARA',
#  'KDMN',
#  'XNCR',
#  'ACHN',
#  'ARNA',
#  'RCKT',
#  'TBIO',
#  'VYGR',
#  'SGMO',
#  'ODT',
#  'ANAB',
#  'ATRA',
#  'CNST',
#  'GERN',
#  'BPMC',
#  'ALLO',
#  'BBIO',
#  'FGEN',
#  'PGNX',
#  'MGTX',
#  'NXTC',
#  'IMMU',
#  'ZIOP',
#  'CRSP',
#  'IOVA',
#  'VKTX',
#  'EIDX',
#  'MYOV',
#  'AMRS',
#  'KRYS',
#  'KURA',
#  'MDGL',
#  'UBX',
#  'TCDA',
#  'QURE',
#  'MRTX',
#  'ASMB',
#  'GLYC',
#  'RYTM',
#  'FIXX',
#  'DRNA',
#  'ARWR',
#  'ALLK',
#  'GOSS',
#  'WVE']
